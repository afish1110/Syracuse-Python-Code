# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import numpy as np
import pandas as pd

# %%
from nba_api.stats.static import teams
##scraping team data
nba_teams = teams.get_teams()
timberwolves = [team for team in nba_teams if team['nickname'] == 'Timberwolves'][0]
bucks = [team for team in nba_teams if team['nickname'] == 'Bucks'][0]
bulls = [team for team in nba_teams if team['nickname'] == 'Bulls'][0]
##stores the team id of each of the 3 nba teams
tw_id = timberwolves['id']
bucks_id = bucks['id']
bulls_id = bulls['id']

# %%
##finding the games for the teams
from nba_api.stats.endpoints import leaguegamefinder
##Timberwolves
tw_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable = tw_id)
tw_games = tw_gamefinder.get_data_frames()[0]
tw_2019 = tw_games[tw_games.SEASON_ID.str[-4:] == '2019']

##Bucks
bucks_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable = bucks_id)
bucks_games = bucks_gamefinder.get_data_frames()[0]
bucks_2019 = bucks_games[bucks_games.SEASON_ID.str[-4:] == '2019']

##Bulls
bulls_gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable = bulls_id)
bulls_games = bulls_gamefinder.get_data_frames()[0]
bulls_2019 = bulls_games[bulls_games.SEASON_ID.str[-4:] == '2019']

# %%
combined_teams = pd.concat([tw_2019, bucks_2019, bulls_2019])
combined_teams.to_csv('WolvesBucksBulls2019.csv', index = False, na_rep = 'NULL')
data2019 = pd.read_csv('WolvesBucksBulls2019.csv')
data2019.head()
data2019.tail()
# Out:
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME   GAME_ID  \
# 0      22019  1610612750               MIN  Minnesota Timberwolves  21900963
# 1      22019  1610612750               MIN  Minnesota Timberwolves  21900947
# 2      22019  1610612750               MIN  Minnesota Timberwolves  21900935
# 3      22019  1610612750               MIN  Minnesota Timberwolves  21900922
# 4      22019  1610612750               MIN  Minnesota Timberwolves  21900911
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2020-03-10    MIN @ HOU  L  240  111  ...   0.739     8    33   41   21
# 1  2020-03-08  MIN vs. NOP  L  240  107  ...   0.806     9    33   42   20
# 2  2020-03-06  MIN vs. ORL  L  240  118  ...   0.800    10    26   36   30
# 3  2020-03-04  MIN vs. CHI  W  240  115  ...   0.640    10    33   43   27
# 4  2020-03-03    MIN @ NOP  W  241  139  ...   0.850    10    32   42   31
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    9    0   18  20        -6.0
# 1   15    3   17  23       -13.0
# 2    6    3    8  21       -14.0
# 3    5    4   17  15         7.0
# 4   11    2   16  22         5.0
#
# [5 rows x 28 columns]
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION      TEAM_NAME     GAME_ID  \
# 242      22019  1610612741               CHI  Chicago Bulls  1521900077
# 243      22019  1610612741               CHI  Chicago Bulls  1521900051
# 244      22019  1610612741               CHI  Chicago Bulls  1521900037
# 245      22019  1610612741               CHI  Chicago Bulls  1521900025
# 246      22019  1610612741               CHI  Chicago Bulls  1521900006
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 242  2019-07-13  CHI vs. ORL  L  200   73  ...   0.692     5    29   34   17
# 243  2019-07-10  CHI vs. CHA  W  199   75  ...   0.792    17    34   51   11
# 244  2019-07-08  CHI vs. NOP  L  200   72  ...   0.650     9    27   36   10
# 245  2019-07-07    CHI @ CLE  L  201   75  ...   0.800     3    28   31   15
# 246  2019-07-05  CHI vs. LAL  W  201   96  ...   0.767    11    35   46   15
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 242    6    4   19  17       -11.8
# 243    8    2   16  18         1.0
# 244    9    9   19  24       -33.4
# 245    6    1   14  15        -7.0
# 246   14    6   14  24        15.6
#
# [5 rows x 28 columns]
